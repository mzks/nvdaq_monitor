# %% [markdown]
# # nvdaq_monitor
# Keita Mizukoshi (kobe)

# %% [markdown]
# This tool is for quick-check of nVeto DAQ.

# %%
import nvdaq_monitor
man = nvdaq_monitor.manager()

# %%
man = nvdaq_monitor.manager()

# %%
### Usage 1: Find the latest file in the directory
man.find_latest_file() # or, man.fine_latest_file(dir_name)

# %%
### Usage 2: Explicit path
# man.data_name = 'path/to/new_data'

# %%
man.load_data()
man.process() # Collect data and reconstruct for events
# Out:
#   1%|          | 1990/161604 [00:00<00:08, 19898.98it/s]
# Target file:  /Users/mzks/xenon/daq_test/nvdaq_monitor/nvdaq_monitor/data/xenondaq_reader_0_140443912218368
# 100%|██████████| 161604/161604 [00:05<00:00, 27229.92it/s]
# True

# %% [markdown]
# After `man.process()`, we can use the following functions.
#  - show_rate()
#  - show_area(channel)
#  - show_areas()
#  - show_timing(channel)
#  - show_timings()
#  - show_baseline(channel)
#  - show_baselines()
#  - show_pulse(channel, event)

# %%
man.show_rates()

# %%
man.show_areas()

# %%
man.show_timings()

# %%
man.show_baselines()

# %%
man.show_diff_times()

# %%
man.show_pulse(channel=0 , event=0)
man.show_pulse(channel=12, event=0)

# %%
# If you want, you can set hist_range and bins
man.show_diff_times(hist_range=(44000,45000), bins=100)
